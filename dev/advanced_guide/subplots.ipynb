# %%
import folium
import branca

# %% [markdown]
# ## Subplots
#
# ### Two maps in one figure
#
# A `Map` automatically creates a `Figure` to put itself in. You can also do this
# manually, or in this example, create subplots to have two maps in one figure.

# %%
fig = branca.element.Figure()

subplot1 = fig.add_subplot(1, 2, 1)
subplot2 = fig.add_subplot(1, 2, 2)

subplot1.add_child(
    folium.Map([0, 0], zoom_start=1)
)
subplot2.add_child(
    folium.Map([46, 3], tiles="OpenStreetMap", zoom_start=5)
)

fig
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5f987aa3b374712eb864eb173fbbf01 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;style&gt; #div_cb76e20aa1db008c1ec59469cb96fd86 {
#         position : absolute;
#         width : 45.0%;
#         height: 90.0%;
#         left: 2.5%;
#         top: 5.0%;
#     &lt;/style&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b9ce8aa15251de2564bdabb2bde71a52 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;style&gt; #div_c6c238397ecd158f8e9ff544a5d71bf1 {
#         position : absolute;
#         width : 45.0%;
#         height: 90.0%;
#         left: 52.5%;
#         top: 5.0%;
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div id=&quot;div_cb76e20aa1db008c1ec59469cb96fd86&quot;&gt;
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5f987aa3b374712eb864eb173fbbf01&quot; &gt;&lt;/div&gt;
#         &lt;/div&gt;
#     &lt;div id=&quot;div_c6c238397ecd158f8e9ff544a5d71bf1&quot;&gt;
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b9ce8aa15251de2564bdabb2bde71a52&quot; &gt;&lt;/div&gt;
#         &lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5f987aa3b374712eb864eb173fbbf01 = L.map(
#                 &quot;map_d5f987aa3b374712eb864eb173fbbf01&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_167d6e7f605c0232b8a6d0341af60168 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_167d6e7f605c0232b8a6d0341af60168.addTo(map_d5f987aa3b374712eb864eb173fbbf01);
#
#
#             var map_b9ce8aa15251de2564bdabb2bde71a52 = L.map(
#                 &quot;map_b9ce8aa15251de2564bdabb2bde71a52&quot;,
#                 {
#                     center: [46.0, 3.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6c81f1653a6b904706bbd3aefabfcc1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c6c81f1653a6b904706bbd3aefabfcc1.addTo(map_b9ce8aa15251de2564bdabb2bde71a52);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Vega div and a Map
#
# Here we create a single figure in which we'll embed two maps and two Vega charts.
# Note that this also works with `VegaLite`.

# %%
import json

import numpy as np
import vincent


multi_iter2 = {
    "x": np.random.uniform(size=(100,)),
    "y": np.random.uniform(size=(100,)),
}
scatter = vincent.Scatter(multi_iter2, iter_idx="x", height=250, width=420)
data = json.loads(scatter.to_json())

f = branca.element.Figure()

# Create two maps.
m = folium.Map(
    location=[0, 0],
    zoom_start=1,
    position="absolute",
    left="0%",
    width="50%",
    height="50%",
)

m2 = folium.Map(
    location=[46, 3],
    tiles="OpenStreetMap",
    zoom_start=4,
    position="absolute",
    left="50%",
    width="50%",
    height="50%",
    top="50%",
)

# Create two Vega charts
v = folium.Vega(data, position="absolute", left="50%", width="50%", height="50%")

v2 = folium.Vega(
    data, position="absolute", left="0%", width="50%", height="50%", top="50%"
)

f.add_child(m)
f.add_child(m2)
f.add_child(v)
f.add_child(v2)

f
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d144e021184b4150e79aa09cc7fc66f6 {
#                     position: absolute;
#                     width: 50.0%;
#                     height: 50.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c87c7ffec5bc5aaaf4be1d53d7688a1 {
#                     position: absolute;
#                     width: 50.0%;
#                     height: 50.0%;
#                     left: 50.0%;
#                     top: 50.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/vega/1.4.3/vega.min.js&quot;&gt;&lt;/script&gt;
#
#             &lt;style&gt; #vega_819a9b3b3b4d2c491e678bc4198f73ce {
#                 position : absolute;
#                 width : 50.0%;
#                 height: 50.0%;
#                 left: 50.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_ebf216dae4e9e8a9ef449db80ba0d8b5 {
#                 position : absolute;
#                 width : 50.0%;
#                 height: 50.0%;
#                 left: 0.0%;
#                 top: 50.0%;
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d144e021184b4150e79aa09cc7fc66f6&quot; &gt;&lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c87c7ffec5bc5aaaf4be1d53d7688a1&quot; &gt;&lt;/div&gt;
#
#
#             &lt;div id=&quot;vega_819a9b3b3b4d2c491e678bc4198f73ce&quot;&gt;&lt;/div&gt;
#
#
#             &lt;div id=&quot;vega_ebf216dae4e9e8a9ef449db80ba0d8b5&quot;&gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d144e021184b4150e79aa09cc7fc66f6 = L.map(
#                 &quot;map_d144e021184b4150e79aa09cc7fc66f6&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e14ec23612ece504231bc6752fb6b34b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e14ec23612ece504231bc6752fb6b34b.addTo(map_d144e021184b4150e79aa09cc7fc66f6);
#
#
#             var map_2c87c7ffec5bc5aaaf4be1d53d7688a1 = L.map(
#                 &quot;map_2c87c7ffec5bc5aaaf4be1d53d7688a1&quot;,
#                 {
#                     center: [46.0, 3.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d96ec7933cea3d6a630e56b11ddd871 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3d96ec7933cea3d6a630e56b11ddd871.addTo(map_2c87c7ffec5bc5aaaf4be1d53d7688a1);
#
#
#             vega_parse({&quot;axes&quot;: [{&quot;scale&quot;: &quot;x&quot;, &quot;type&quot;: &quot;x&quot;}, {&quot;scale&quot;: &quot;y&quot;, &quot;type&quot;: &quot;y&quot;}], &quot;data&quot;: [{&quot;name&quot;: &quot;table&quot;, &quot;values&quot;: [{&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.9490658756152436, &quot;val&quot;: 0.5650959785295723}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.9260674698213084, &quot;val&quot;: 0.6299134277899268}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.0939474480464767, &quot;val&quot;: 0.6342195341843965}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.5527041134906736, &quot;val&quot;: 0.13794043601296913}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.2757023567882678, &quot;val&quot;: 0.23197081493630856}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.7827239843194589, &quot;val&quot;: 0.47238656598546347}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.3787572074556589, &quot;val&quot;: 0.4234620880380262}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.8983286850225524, &quot;val&quot;: 0.9688069164723675}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.4190950559441552, &quot;val&quot;: 0.2591102968590555}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.5649113641104688, &quot;val&quot;: 0.5773228912996721}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.11601845108758813, &quot;va
