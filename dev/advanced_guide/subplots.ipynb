# %%
import folium
import branca

# %% [markdown]
# ## Subplots
#
# ### Two maps in one figure
#
# A `Map` automatically creates a `Figure` to put itself in. You can also do this
# manually, or in this example, create subplots to have two maps in one figure.

# %%
fig = branca.element.Figure()

subplot1 = fig.add_subplot(1, 2, 1)
subplot2 = fig.add_subplot(1, 2, 2)

subplot1.add_child(
    folium.Map([0, 0], zoom_start=1)
)
subplot2.add_child(
    folium.Map([46, 3], tiles="OpenStreetMap", zoom_start=5)
)

fig
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_54cacf3377df7aae1db82bb79ae89d8e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;style&gt; #div_436f37b49271000d107cd9dda1698666 {
#         position : absolute;
#         width : 45.0%;
#         height: 90.0%;
#         left: 2.5%;
#         top: 5.0%;
#     &lt;/style&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7eaeb022464a5548cc9298f7aae0405a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;style&gt; #div_7465bdf610c78b62a352ef347377151b {
#         position : absolute;
#         width : 45.0%;
#         height: 90.0%;
#         left: 52.5%;
#         top: 5.0%;
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div id=&quot;div_436f37b49271000d107cd9dda1698666&quot;&gt;
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_54cacf3377df7aae1db82bb79ae89d8e&quot; &gt;&lt;/div&gt;
#         &lt;/div&gt;
#     &lt;div id=&quot;div_7465bdf610c78b62a352ef347377151b&quot;&gt;
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7eaeb022464a5548cc9298f7aae0405a&quot; &gt;&lt;/div&gt;
#         &lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_54cacf3377df7aae1db82bb79ae89d8e = L.map(
#                 &quot;map_54cacf3377df7aae1db82bb79ae89d8e&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_562313629f4e0472de81bb7d43ace5db = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_562313629f4e0472de81bb7d43ace5db.addTo(map_54cacf3377df7aae1db82bb79ae89d8e);
#
#
#             var map_7eaeb022464a5548cc9298f7aae0405a = L.map(
#                 &quot;map_7eaeb022464a5548cc9298f7aae0405a&quot;,
#                 {
#                     center: [46.0, 3.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d3708555f9d49badc5c7c411e89b9f70 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d3708555f9d49badc5c7c411e89b9f70.addTo(map_7eaeb022464a5548cc9298f7aae0405a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Vega div and a Map
#
# Here we create a single figure in which we'll embed two maps and two Vega charts.
# Note that this also works with `VegaLite`.

# %%
import json

import numpy as np
import vincent


multi_iter2 = {
    "x": np.random.uniform(size=(100,)),
    "y": np.random.uniform(size=(100,)),
}
scatter = vincent.Scatter(multi_iter2, iter_idx="x", height=250, width=420)
data = json.loads(scatter.to_json())

f = branca.element.Figure()

# Create two maps.
m = folium.Map(
    location=[0, 0],
    zoom_start=1,
    position="absolute",
    left="0%",
    width="50%",
    height="50%",
)

m2 = folium.Map(
    location=[46, 3],
    tiles="OpenStreetMap",
    zoom_start=4,
    position="absolute",
    left="50%",
    width="50%",
    height="50%",
    top="50%",
)

# Create two Vega charts
v = folium.Vega(data, position="absolute", left="50%", width="50%", height="50%")

v2 = folium.Vega(
    data, position="absolute", left="0%", width="50%", height="50%", top="50%"
)

f.add_child(m)
f.add_child(m2)
f.add_child(v)
f.add_child(v2)

f
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e6160b04cd92c16b9cf0f9e6906e0d42 {
#                     position: absolute;
#                     width: 50.0%;
#                     height: 50.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5534da9cda731dc740dfa83ded2f4693 {
#                     position: absolute;
#                     width: 50.0%;
#                     height: 50.0%;
#                     left: 50.0%;
#                     top: 50.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/vega/1.4.3/vega.min.js&quot;&gt;&lt;/script&gt;
#
#             &lt;style&gt; #vega_249577d2128a51552b271084edf2cea4 {
#                 position : absolute;
#                 width : 50.0%;
#                 height: 50.0%;
#                 left: 50.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_9bb7509d0fc952e5a735311153ad464d {
#                 position : absolute;
#                 width : 50.0%;
#                 height: 50.0%;
#                 left: 0.0%;
#                 top: 50.0%;
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e6160b04cd92c16b9cf0f9e6906e0d42&quot; &gt;&lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5534da9cda731dc740dfa83ded2f4693&quot; &gt;&lt;/div&gt;
#
#
#             &lt;div id=&quot;vega_249577d2128a51552b271084edf2cea4&quot;&gt;&lt;/div&gt;
#
#
#             &lt;div id=&quot;vega_9bb7509d0fc952e5a735311153ad464d&quot;&gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e6160b04cd92c16b9cf0f9e6906e0d42 = L.map(
#                 &quot;map_e6160b04cd92c16b9cf0f9e6906e0d42&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_00cff6257917e868edbeee6c408289b7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_00cff6257917e868edbeee6c408289b7.addTo(map_e6160b04cd92c16b9cf0f9e6906e0d42);
#
#
#             var map_5534da9cda731dc740dfa83ded2f4693 = L.map(
#                 &quot;map_5534da9cda731dc740dfa83ded2f4693&quot;,
#                 {
#                     center: [46.0, 3.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_628b00147ba71bc23a69505114c27e9e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_628b00147ba71bc23a69505114c27e9e.addTo(map_5534da9cda731dc740dfa83ded2f4693);
#
#
#             vega_parse({&quot;axes&quot;: [{&quot;scale&quot;: &quot;x&quot;, &quot;type&quot;: &quot;x&quot;}, {&quot;scale&quot;: &quot;y&quot;, &quot;type&quot;: &quot;y&quot;}], &quot;data&quot;: [{&quot;name&quot;: &quot;table&quot;, &quot;values&quot;: [{&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.577819691664979, &quot;val&quot;: 0.12630427916153097}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.7982134581340651, &quot;val&quot;: 0.458466183891051}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.9167093589888172, &quot;val&quot;: 0.5118003022477501}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.8712875655870482, &quot;val&quot;: 0.6443899108193787}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.6936187871982153, &quot;val&quot;: 0.5325788752708538}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.6581702524041192, &quot;val&quot;: 0.6149836488498716}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.7877314075947166, &quot;val&quot;: 0.8576247295678991}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.7567441749970933, &quot;val&quot;: 0.9118175326346775}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.5184538636005592, &quot;val&quot;: 0.8026273485353651}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.8702650745282124, &quot;val&quot;: 0.9298512053166907}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.8809685956659629, &quot;val&quo
