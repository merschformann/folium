# %% [markdown]
# # Popups
#
# ## Simple popups
#
# You can define your popup at the feature creation, but you can also overwrite them afterwards:

# %%
import folium


m = folium.Map([45, 0], zoom_start=4)

folium.Marker([45, -30], popup="inline implicit popup").add_to(m)

folium.CircleMarker(
    location=[45, -10],
    radius=25,
    fill=True,
    popup=folium.Popup("inline explicit Popup"),
).add_to(m)

ls = folium.PolyLine(
    locations=[[43, 7], [43, 13], [47, 13], [47, 7], [43, 7]], color="red"
)

ls.add_child(folium.Popup("outline Popup on Polyline"))
ls.add_to(m)

gj = folium.GeoJson(
    data={"type": "Polygon", "coordinates": [[[27, 43], [33, 43], [33, 47], [27, 47]]]}
)

gj.add_child(folium.Popup("outline Popup on GeoJSON"))
gj.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff21187c6da6fcbb2e1e65b65e4086c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff21187c6da6fcbb2e1e65b65e4086c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff21187c6da6fcbb2e1e65b65e4086c7 = L.map(
#                 &quot;map_ff21187c6da6fcbb2e1e65b65e4086c7&quot;,
#                 {
#                     center: [45.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5279200772491e97f34d83d3bc26633 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a5279200772491e97f34d83d3bc26633.addTo(map_ff21187c6da6fcbb2e1e65b65e4086c7);
#
#
#             var marker_93f3f6f7fa1401bf5efd59b06b908245 = L.marker(
#                 [45.0, -30.0],
#                 {}
#             ).addTo(map_ff21187c6da6fcbb2e1e65b65e4086c7);
#
#
#         var popup_aa977db1a66c0af52e4940a048e0de85 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aaf22ff7891ba76682f312107bf5662c = $(`&lt;div id=&quot;html_aaf22ff7891ba76682f312107bf5662c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;inline implicit popup&lt;/div&gt;`)[0];
#                 popup_aa977db1a66c0af52e4940a048e0de85.setContent(html_aaf22ff7891ba76682f312107bf5662c);
#
#
#
#         marker_93f3f6f7fa1401bf5efd59b06b908245.bindPopup(popup_aa977db1a66c0af52e4940a048e0de85)
#         ;
#
#
#
#
#             var circle_marker_983aa9a24c6db6872d24af627fff7f53 = L.circleMarker(
#                 [45.0, -10.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 25, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ff21187c6da6fcbb2e1e65b65e4086c7);
#
#
#         var popup_ccd1ec3c9617750d1b4a1b965576d62b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bf346b02331ca884acef3f2c65843ca3 = $(`&lt;div id=&quot;html_bf346b02331ca884acef3f2c65843ca3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;inline explicit Popup&lt;/div&gt;`)[0];
#                 popup_ccd1ec3c9617750d1b4a1b965576d62b.setContent(html_bf346b02331ca884acef3f2c65843ca3);
#
#
#
#         circle_marker_983aa9a24c6db6872d24af627fff7f53.bindPopup(popup_ccd1ec3c9617750d1b4a1b965576d62b)
#         ;
#
#
#
#
#             var poly_line_89d33f7d76433b08dae011ce9294f175 = L.polyline(
#                 [[43.0, 7.0], [43.0, 13.0], [47.0, 13.0], [47.0, 7.0], [43.0, 7.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ff21187c6da6fcbb2e1e65b65e4086c7);
#
#
#         var popup_98795d1c6b46ea2dbfc841939cdb75da = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6dd6087ba7df1a14ac22a755f7b54cde = $(`&lt;div id=&quot;html_6dd6087ba7df1a14ac22a755f7b54cde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;outline Popup on Polyline&lt;/div&gt;`)[0];
#                 popup_98795d1c6b46ea2dbfc841939cdb75da.setContent(html_6dd6087ba7df1a14ac22a755f7b54cde);
#
#
#
#         poly_line_89d33f7d76433b08dae011ce9294f175.bindPopup(popup_98795d1c6b46ea2dbfc841939cdb75da)
#         ;
#
#
#
#
#
#         function geo_json_3073a2ebe2ec02a12c3e3544a4675152_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_3073a2ebe2ec02a12c3e3544a4675152 = L.geoJson(null, {
#                 onEachFeature: geo_json_3073a2ebe2ec02a12c3e3544a4675152_onEachFeature,
#
#         });
#
#         function geo_json_3073a2ebe2ec02a12c3e3544a4675152_add (data) {
#             geo_json_3073a2ebe2ec02a12c3e3544a4675152
#                 .addData(data);
#         }
#             geo_json_3073a2ebe2ec02a12c3e3544a4675152_add({&quot;coordinates&quot;: [[[27, 43], [33, 43], [33, 47], [27, 47]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_3073a2ebe2ec02a12c3e3544a4675152.setStyle(function(feature) {return featu

# %%
m = folium.Map([45, 0], zoom_start=2)

folium.Marker(
    location=[45, -10],
    popup=folium.Popup("Let's try quotes", parse_html=True, max_width=100),
).add_to(m)

folium.Marker(
    location=[45, -30],
    popup=folium.Popup(u"Ça c'est chouette", parse_html=True, max_width="100%"),
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d24b9c1724bab7a638b5a189c36e9e7b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d24b9c1724bab7a638b5a189c36e9e7b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d24b9c1724bab7a638b5a189c36e9e7b = L.map(
#                 &quot;map_d24b9c1724bab7a638b5a189c36e9e7b&quot;,
#                 {
#                     center: [45.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1ae51fb869600a9e0cd25367489b4a1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b1ae51fb869600a9e0cd25367489b4a1.addTo(map_d24b9c1724bab7a638b5a189c36e9e7b);
#
#
#             var marker_6c5c21c22905bff9dea98911b6adc1e8 = L.marker(
#                 [45.0, -10.0],
#                 {}
#             ).addTo(map_d24b9c1724bab7a638b5a189c36e9e7b);
#
#
#         var popup_b578b4dd78ae7e9ffc07fea549956e88 = L.popup({&quot;maxWidth&quot;: 100});
#
#
#
#                 var html_95d59da85f80bb55210f903c25760d5f = $(`&lt;div id=&quot;html_95d59da85f80bb55210f903c25760d5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Let&amp;#39;s try quotes&lt;/div&gt;`)[0];
#                 popup_b578b4dd78ae7e9ffc07fea549956e88.setContent(html_95d59da85f80bb55210f903c25760d5f);
#
#
#
#         marker_6c5c21c22905bff9dea98911b6adc1e8.bindPopup(popup_b578b4dd78ae7e9ffc07fea549956e88)
#         ;
#
#
#
#
#             var marker_c6d50272de34eb2b8f39a6ba4d5adc08 = L.marker(
#                 [45.0, -30.0],
#                 {}
#             ).addTo(map_d24b9c1724bab7a638b5a189c36e9e7b);
#
#
#         var popup_e8393ced3a27df80bacbad181ff6e4ed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7814ab8a47e45798a424127e702e11ea = $(`&lt;div id=&quot;html_7814ab8a47e45798a424127e702e11ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ça c&amp;#39;est chouette&lt;/div&gt;`)[0];
#                 popup_e8393ced3a27df80bacbad181ff6e4ed.setContent(html_7814ab8a47e45798a424127e702e11ea);
#
#
#
#         marker_c6d50272de34eb2b8f39a6ba4d5adc08.bindPopup(popup_e8393ced3a27df80bacbad181ff6e4ed)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## HTML in popup

# %%
import branca

m = folium.Map([43, -100], zoom_start=4)

html = """
    <h1> This is a big popup</h1><br>
    With a few lines of code...
    <p>
    <code>
        from numpy import *<br>
        exp(-2*pi)
    </code>
    </p>
    """


folium.Marker([30, -100], popup=html).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f1d7195907890a4fd38ca11740b23e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f1d7195907890a4fd38ca11740b23e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f1d7195907890a4fd38ca11740b23e1 = L.map(
#                 &quot;map_1f1d7195907890a4fd38ca11740b23e1&quot;,
#                 {
#                     center: [43.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf97a2ad736697185b8dd1a8cd440df6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cf97a2ad736697185b8dd1a8cd440df6.addTo(map_1f1d7195907890a4fd38ca11740b23e1);
#
#
#             var marker_3c5131386708beaa814d3fb30c750a77 = L.marker(
#                 [30.0, -100.0],
#                 {}
#             ).addTo(map_1f1d7195907890a4fd38ca11740b23e1);
#
#
#         var popup_2a2153f2e7eb5cb5d67c196be9c676a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6211b742c9799d4a8db093afe2e3f9b1 = $(`&lt;div id=&quot;html_6211b742c9799d4a8db093afe2e3f9b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;h1&gt; This is a big popup&lt;/h1&gt;&lt;br&gt;     With a few lines of code...     &lt;p&gt;     &lt;code&gt;         from numpy import *&lt;br&gt;         exp(-2*pi)     &lt;/code&gt;     &lt;/p&gt;     &lt;/div&gt;`)[0];
#                 popup_2a2153f2e7eb5cb5d67c196be9c676a5.setContent(html_6211b742c9799d4a8db093afe2e3f9b1);
#
#
#
#         marker_3c5131386708beaa814d3fb30c750a77.bindPopup(popup_2a2153f2e7eb5cb5d67c196be9c676a5)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Iframe in popup
#
# You can also put any HTML code inside a Popup, thaks to the `IFrame` object.

# %%
m = folium.Map([43, -100], zoom_start=4)

html = """
    <h1> This popup is an Iframe</h1><br>
    With a few lines of code...
    <p>
    <code>
        from numpy import *<br>
        exp(-2*pi)
    </code>
    </p>
    """

iframe = branca.element.IFrame(html=html, width=500, height=300)
popup = folium.Popup(iframe, max_width=500)

folium.Marker([30, -100], popup=popup).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b43daf6affda80abc85f40d8eb3b1f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b43daf6affda80abc85f40d8eb3b1f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b43daf6affda80abc85f40d8eb3b1f2 = L.map(
#                 &quot;map_0b43daf6affda80abc85f40d8eb3b1f2&quot;,
#                 {
#                     center: [43.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_64c35aa8a0ed8ef6f0dba1185623340a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_64c35aa8a0ed8ef6f0dba1185623340a.addTo(map_0b43daf6affda80abc85f40d8eb3b1f2);
#
#
#             var marker_dd6ef050629402f4200d336ace561384 = L.marker(
#                 [30.0, -100.0],
#                 {}
#             ).addTo(map_0b43daf6affda80abc85f40d8eb3b1f2);
#
#
#         var popup_e22309bcf13c93902d3ddfef66a11c0d = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var i_frame_3538235e9a49bf501c281341e9498b80 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICAKICAgIDxoMT4gVGhpcyBwb3B1cCBpcyBhbiBJZnJhbWU8L2gxPjxicj4KICAgIFdpdGggYSBmZXcgbGluZXMgb2YgY29kZS4uLgogICAgPHA+CiAgICA8Y29kZT4KICAgICAgICBmcm9tIG51bXB5IGltcG9ydCAqPGJyPgogICAgICAgIGV4cCgtMipwaSkKICAgIDwvY29kZT4KICAgIDwvcD4KICAgIA==&quot; width=&quot;500&quot; style=&quot;border:none !important;&quot; height=&quot;300&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_e22309bcf13c93902d3ddfef66a11c0d.setContent(i_frame_3538235e9a49bf501c281341e9498b80);
#
#
#
#         marker_dd6ef050629402f4200d336ace561384.bindPopup(popup_e22309bcf13c93902d3ddfef66a11c0d)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd

df = pd.DataFrame(
    data=[["apple", "oranges"], ["other", "stuff"]], columns=["cats", "dogs"]
)

m = folium.Map([43, -100], zoom_start=4)

html = df.to_html(
    classes="table table-striped table-hover table-condensed table-responsive"
)

popup = folium.Popup(html)

folium.Marker([30, -100], popup=popup).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_60cc95cf6fccd65677285c2a9769acf6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_60cc95cf6fccd65677285c2a9769acf6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_60cc95cf6fccd65677285c2a9769acf6 = L.map(
#                 &quot;map_60cc95cf6fccd65677285c2a9769acf6&quot;,
#                 {
#                     center: [43.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_baea152dd9a546a5b818c1b78323930a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_baea152dd9a546a5b818c1b78323930a.addTo(map_60cc95cf6fccd65677285c2a9769acf6);
#
#
#             var marker_d7ab66898e2239fb3a270b4f359626e0 = L.marker(
#                 [30.0, -100.0],
#                 {}
#             ).addTo(map_60cc95cf6fccd65677285c2a9769acf6);
#
#
#         var popup_e93bd095b361277e8f34115319c72405 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ad10b47a60c43500c0419ae8bce9d6c2 = $(`&lt;div id=&quot;html_ad10b47a60c43500c0419ae8bce9d6c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;table border=&quot;1&quot; class=&quot;dataframe table table-striped table-hover table-condensed table-responsive&quot;&gt;   &lt;thead&gt;     &lt;tr style=&quot;text-align: right;&quot;&gt;       &lt;th&gt;&lt;/th&gt;       &lt;th&gt;cats&lt;/th&gt;       &lt;th&gt;dogs&lt;/th&gt;     &lt;/tr&gt;   &lt;/thead&gt;   &lt;tbody&gt;     &lt;tr&gt;       &lt;th&gt;0&lt;/th&gt;       &lt;td&gt;apple&lt;/td&gt;       &lt;td&gt;oranges&lt;/td&gt;     &lt;/tr&gt;     &lt;tr&gt;       &lt;th&gt;1&lt;/th&gt;       &lt;td&gt;other&lt;/td&gt;       &lt;td&gt;stuff&lt;/td&gt;     &lt;/tr&gt;   &lt;/tbody&gt; &lt;/table&gt;&lt;/div&gt;`)[0];
#                 popup_e93bd095b361277e8f34115319c72405.setContent(html_ad10b47a60c43500c0419ae8bce9d6c2);
#
#
#
#         marker_d7ab66898e2239fb3a270b4f359626e0.bindPopup(popup_e93bd095b361277e8f34115319c72405)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Note that you can put another `Figure` into an `IFrame` ; this should let you do strange things...

# %%
# Let's create a Figure, with a map inside.
f = branca.element.Figure()
folium.Map([-25, 150], zoom_start=3).add_to(f)

# Let's put the figure into an IFrame.
iframe = branca.element.IFrame(width=500, height=300)
f.add_to(iframe)

# Let's put the IFrame in a Popup
popup = folium.Popup(iframe, max_width=2650)

# Let's create another map.
m = folium.Map([43, -100], zoom_start=4)

# Let's put the Popup on a marker, in the second map.
folium.Marker([30, -100], popup=popup).add_to(m)

# We get a map in a Popup. Not really useful, but powerful.
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35c9206ea7d66e8fc8da187a3fcce5f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35c9206ea7d66e8fc8da187a3fcce5f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35c9206ea7d66e8fc8da187a3fcce5f7 = L.map(
#                 &quot;map_35c9206ea7d66e8fc8da187a3fcce5f7&quot;,
#                 {
#                     center: [43.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b7f89099f6b240f8c0f8618348f1068 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3b7f89099f6b240f8c0f8618348f1068.addTo(map_35c9206ea7d66e8fc8da187a3fcce5f7);
#
#
#             var marker_a7f23af097a576677b3c90d8ef81cbf0 = L.marker(
#                 [30.0, -100.0],
#                 {}
#             ).addTo(map_35c9206ea7d66e8fc8da187a3fcce5f7);
#
#
#         var popup_d3fe09895972ae18e823d05487c77575 = L.popup({&quot;maxWidth&quot;: 2650});
#
#
#
#                 var i_frame_499b00256e5ec31206e1afe4b6a937e9 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;500&quot; style=&quot;border:none !important;&quot; height=&quot;300&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_d3fe09895972ae18e823d05487c77575.setContent(i_frame_499b00256e5ec31206e1afe4b6a937e9);
#
#
#
#         marker_a7f23af097a576677b3c90d8ef81cbf0.bindPopup(popup_d3fe09895972ae18e823d05487c77575)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Vega chart in popup
#
# [Vega](https://vega.github.io/vega/) is a way to describe charts. You can embed
# a Vega chart in a popup using the `Vega` class.

# %%
import json

import numpy as np
import vincent

multi_iter2 = {
    "x": np.random.uniform(size=(100,)),
    "y": np.random.uniform(size=(100,)),
}
scatter = vincent.Scatter(multi_iter2, iter_idx="x", height=100, width=200)
data = json.loads(scatter.to_json())

m = folium.Map([0, 0], zoom_start=1)
marker = folium.Marker([0, 0]).add_to(m)
popup = folium.Popup("Hello").add_to(marker)
folium.Vega(data, width="100%", height="100%").add_to(popup)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c59706d86f7c5a75a85ce292ff9ac664 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/vega/1.4.3/vega.min.js&quot;&gt;&lt;/script&gt;
#
#             &lt;style&gt; #vega_df14ebcd2a54d32d7c8370d987b60643 {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c59706d86f7c5a75a85ce292ff9ac664&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c59706d86f7c5a75a85ce292ff9ac664 = L.map(
#                 &quot;map_c59706d86f7c5a75a85ce292ff9ac664&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_12f81808bdce9aabb692d3e76e399ddb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_12f81808bdce9aabb692d3e76e399ddb.addTo(map_c59706d86f7c5a75a85ce292ff9ac664);
#
#
#             var marker_406dcea2193957696fc2864d864f2307 = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_c59706d86f7c5a75a85ce292ff9ac664);
#
#     function vega_parse(spec, div) {
#             vg.parse.spec(spec, function(chart) { chart({el:div}).update(); });}
#
#         var popup_5d90ca8a0adc9c241d2dd092d70a1073 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_adf87513cdbe094df0deae77adc7ae8a = $(`&lt;div id=&quot;html_adf87513cdbe094df0deae77adc7ae8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hello&lt;/div&gt;`)[0];
#                 popup_5d90ca8a0adc9c241d2dd092d70a1073.setContent(html_adf87513cdbe094df0deae77adc7ae8a);
#
#
#
#                 var vega_df14ebcd2a54d32d7c8370d987b60643 = $(`             &lt;div id=&quot;vega_df14ebcd2a54d32d7c8370d987b60643&quot;&gt;&lt;/div&gt;             `)[0];
#                 popup_5d90ca8a0adc9c241d2dd092d70a1073.setContent(vega_df14ebcd2a54d32d7c8370d987b60643);
#
#
#
#         marker_406dcea2193957696fc2864d864f2307.bindPopup(popup_5d90ca8a0adc9c241d2dd092d70a1073)
#         ;
#
#
#
#             vega_parse({&quot;axes&quot;: [{&quot;scale&quot;: &quot;x&quot;, &quot;type&quot;: &quot;x&quot;}, {&quot;scale&quot;: &quot;y&quot;, &quot;type&quot;: &quot;y&quot;}], &quot;data&quot;: [{&quot;name&quot;: &quot;table&quot;, &quot;values&quot;: [{&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.06480787940540234, &quot;val&quot;: 0.14055271224671917}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.6008933120368892, &quot;val&quot;: 0.9385973440869322}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.839908140062022, &quot;val&quot;: 0.47853436323845844}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.8691231803062982, &quot;val&quot;: 0.9238333212486384}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.7921792805141455, &quot;val&quot;: 0.9007711161348552}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.1427197615622321, &quot;val&quot;: 0.08089777239777085}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.9960477400163504, &quot;val&quot;: 0.844725927529689}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.5938481290793399, &quot;val&quot;: 0.9106052338251596}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.709119682561979, &quot;val&quot;: 0.8604265016116637}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.6114866379615129, &quot;val&quot;: 0.17462459263706875}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.7758332675098458, &quot;val&quot;: 0.5629640906070127}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.5458601764904063, &quot;val&quot;: 0.275998624266652}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.5124342353970792, &quot;val&quot;: 0.36273889378107993}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.6833081398326789, &quot;val&quot;: 0.27263402914191526}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.6272667416931486, &quot;val&quot;: 0.9534034351147094}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.6182711947404936, &quot;val&quot;: 0.6911673268514033}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.7949899236996405, &quot;val&quot;: 0.6821582550864268}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.15533030068868414, &quot;val&quot;: 0.30450619356739794}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.14577008282912152, &quot;val&quot;: 0.7640250368525606}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.2638283069998175, &quot;val&quot;: 0.9277862782597623}, {&quot;col&quot;: &quot;y&quot;, &quot

# %% [markdown]
# ## Vega-Lite chart in popup
#
# [Vega-lite](https://vega.github.io/vega-lite/) is a higher-level version of Vega.
# Folium supports it as well in the `VegaLite` class.

# %%
from altair import Chart

import vega_datasets

# load built-in dataset as a pandas DataFrame
cars = vega_datasets.data.cars()

scatter = (
    Chart(cars)
    .mark_circle()
    .encode(
        x="Horsepower",
        y="Miles_per_Gallon",
        color="Origin",
    )
)

vega_lite = folium.VegaLite(
    scatter,
    width="100%",
    height="100%",
)

m = folium.Map(location=[-27.5717, -48.6256])

marker = folium.Marker([-27.57, -48.62])

popup = folium.Popup()

vega_lite.add_to(popup)
popup.add_to(marker)

marker.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f3b7f7fa2474c64132a8910721475c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#             &lt;style&gt; #vega_lite_236342acbc3d8c5a5226057aa1b49a0f {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm//vega@5&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/vega-lite@5&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/vega-embed@6&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f3b7f7fa2474c64132a8910721475c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f3b7f7fa2474c64132a8910721475c3 = L.map(
#                 &quot;map_9f3b7f7fa2474c64132a8910721475c3&quot;,
#                 {
#                     center: [-27.5717, -48.6256],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1a5afe0da73a3093ddb0253ff618ff64 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1a5afe0da73a3093ddb0253ff618ff64.addTo(map_9f3b7f7fa2474c64132a8910721475c3);
#
#
#             var marker_6bbd45b32f26d7547c9b02517f62c8de = L.marker(
#                 [-27.57, -48.62],
#                 {}
#             ).addTo(map_9f3b7f7fa2474c64132a8910721475c3);
#
#
#         var popup_290b19809a06278b30b99a8dc25e50a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var vega_lite_236342acbc3d8c5a5226057aa1b49a0f = $(`             &lt;div id=&quot;vega_lite_236342acbc3d8c5a5226057aa1b49a0f&quot;&gt;&lt;/div&gt;             `)[0];
#                 popup_290b19809a06278b30b99a8dc25e50a4.setContent(vega_lite_236342acbc3d8c5a5226057aa1b49a0f);
#
#
#
#         marker_6bbd45b32f26d7547c9b02517f62c8de.bindPopup(popup_290b19809a06278b30b99a8dc25e50a4)
#         ;
#
#
#
#                     vegaEmbed(vega_lite_236342acbc3d8c5a5226057aa1b49a0f, {&quot;$schema&quot;: &quot;https://vega.github.io/schema/vega-lite/v5.17.0.json&quot;, &quot;config&quot;: {&quot;view&quot;: {&quot;continuousHeight&quot;: 300, &quot;continuousWidth&quot;: 300}}, &quot;data&quot;: {&quot;name&quot;: &quot;data-583e73726c1545c56c203344161a975c&quot;}, &quot;datasets&quot;: {&quot;data-583e73726c1545c56c203344161a975c&quot;: [{&quot;Acceleration&quot;: 12.0, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 307.0, &quot;Horsepower&quot;: 130.0, &quot;Miles_per_Gallon&quot;: 18.0, &quot;Name&quot;: &quot;chevrolet chevelle malibu&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 3504, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 11.5, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 350.0, &quot;Horsepower&quot;: 165.0, &quot;Miles_per_Gallon&quot;: 15.0, &quot;Name&quot;: &quot;buick skylark 320&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 3693, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 11.0, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 318.0, &quot;Horsepower&quot;: 150.0, &quot;Miles_per_Gallon&quot;: 18.0, &quot;Name&quot;: &quot;plymouth satellite&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 3436, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 12.0, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 304.0, &quot;Horsepower&quot;: 150.0, &quot;Miles_per_Gallon&quot;: 16.0, &quot;Name&quot;: &quot;amc rebel sst&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 3433, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 10.5, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 302.0, &quot;Horsepower&quot;: 140.0, &quot;Miles_per_Gallon&quot;: 17.0, &quot;Name&quot;: &quot;ford torino&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 3449, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 10.0, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 429.0, &quot;Horsepower&quot;: 198.0, &quot;Miles_per_Gallon&quot;: 15.0, &quot;Name&quot;: &quot;ford galaxie 500&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 4341, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 9.0, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 454.0, &quot;Horsepower&quot;: 220.0, &quot;Miles_per_Gallon&quot;: 14.0, &quot;Name&quot;: &quot;chevrolet impala&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 4354, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 8.5, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 440.0, &q

# %% [markdown]
# ## Lazy loading
#
# If whatever you are showing in the popup is slow or heavy to load and you have many popups, you may not want to render the popup contents immediately. There's an argument to prevent loading until the popup is opened.

# %%
m = folium.Map([43, -100], zoom_start=4)

html = "{a resource that is heavy to load, such as an image}"

folium.Marker([30, -100], popup=html, lazy=True).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_769d45d5deb30cc329ce283144df9e41 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_769d45d5deb30cc329ce283144df9e41&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_769d45d5deb30cc329ce283144df9e41 = L.map(
#                 &quot;map_769d45d5deb30cc329ce283144df9e41&quot;,
#                 {
#                     center: [43.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82433e28f0b7cadeaa90fc9127a0a69b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_82433e28f0b7cadeaa90fc9127a0a69b.addTo(map_769d45d5deb30cc329ce283144df9e41);
#
#
#             var marker_757cbacb8d2b23673cf4c9490f18bbcb = L.marker(
#                 [30.0, -100.0],
#                 {&quot;lazy&quot;: true}
#             ).addTo(map_769d45d5deb30cc329ce283144df9e41);
#
#
#         var popup_a3cdf25bf687a40636f82284f97dd83e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0b53860d00cb1aa2a0f2df1cdfe984a9 = $(`&lt;div id=&quot;html_0b53860d00cb1aa2a0f2df1cdfe984a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;{a resource that is heavy to load, such as an image}&lt;/div&gt;`)[0];
#                 popup_a3cdf25bf687a40636f82284f97dd83e.setContent(html_0b53860d00cb1aa2a0f2df1cdfe984a9);
#
#
#
#         marker_757cbacb8d2b23673cf4c9490f18bbcb.bindPopup(popup_a3cdf25bf687a40636f82284f97dd83e)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
