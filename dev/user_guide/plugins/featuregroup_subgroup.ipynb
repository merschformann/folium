# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74f66740a96e19547429d5d64fabf158 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74f66740a96e19547429d5d64fabf158&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74f66740a96e19547429d5d64fabf158 = L.map(
#                 &quot;map_74f66740a96e19547429d5d64fabf158&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f302cd947715d34606184c92452bd27 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0f302cd947715d34606184c92452bd27.addTo(map_74f66740a96e19547429d5d64fabf158);
#
#
#             var feature_group_ecc95a05e30451a7e011b86340f0a290 = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_ecc95a05e30451a7e011b86340f0a290.addTo(map_74f66740a96e19547429d5d64fabf158);
#
#
#             var feature_group_sub_group_cd125bab086234afcc0263b7ae1f6e8d = L.featureGroup.subGroup(
#                 feature_group_ecc95a05e30451a7e011b86340f0a290
#             );
#
#
#             var marker_74d875ee19df9cf0278c4f82aaf1055b = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_cd125bab086234afcc0263b7ae1f6e8d);
#
#
#             var marker_c6093210ef4894431699c182b4dc74d3 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_cd125bab086234afcc0263b7ae1f6e8d);
#
#
#             feature_group_sub_group_cd125bab086234afcc0263b7ae1f6e8d.addTo(map_74f66740a96e19547429d5d64fabf158);
#
#
#             var feature_group_sub_group_0f05e4aa6fb4f37b58088100c52bbb1d = L.featureGroup.subGroup(
#                 feature_group_ecc95a05e30451a7e011b86340f0a290
#             );
#
#
#             var marker_b65c7af3a8e3df5a41e7726992aa46a2 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_0f05e4aa6fb4f37b58088100c52bbb1d);
#
#
#             var marker_6bac5e6dff52b1571d8a28222693f533 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_0f05e4aa6fb4f37b58088100c52bbb1d);
#
#
#             feature_group_sub_group_0f05e4aa6fb4f37b58088100c52bbb1d.addTo(map_74f66740a96e19547429d5d64fabf158);
#
#
#             var layer_control_b54897ac98f83101cd3bc21d47a57507_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_0f302cd947715d34606184c92452bd27,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_ecc95a05e30451a7e011b86340f0a290,
#                     &quot;group1&quot; : feature_group_sub_group_cd125bab086234afcc0263b7ae1f6e8d,
#                     &quot;group2&quot; : feature_group_sub_group_0f05e4aa6fb4f37b58088100c52bbb1d,
#                 },
#             };
#             let layer_control_b54897ac98f83101cd3bc21d47a57507 = L.control.layers(
#                 layer_control_b54897ac98f83101cd3bc21d47a57507_layers.base_layers,
#                 layer_control_b54897ac98f83101cd3bc21d47a57507_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_74f66740a96e19547429d5d64fabf158);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_89f5cfae0670fc7d90e14567fb4bc727 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_89f5cfae0670fc7d90e14567fb4bc727&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_89f5cfae0670fc7d90e14567fb4bc727 = L.map(
#                 &quot;map_89f5cfae0670fc7d90e14567fb4bc727&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b84d1915529d108dabef4b12d5f51237 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b84d1915529d108dabef4b12d5f51237.addTo(map_89f5cfae0670fc7d90e14567fb4bc727);
#
#
#             var marker_cluster_31055fe429a9d1cb31c017fa7521e327 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_31055fe429a9d1cb31c017fa7521e327.addTo(map_89f5cfae0670fc7d90e14567fb4bc727);
#
#
#             var feature_group_sub_group_cde09de2476d36b9ddcae14e91293104 = L.featureGroup.subGroup(
#                 marker_cluster_31055fe429a9d1cb31c017fa7521e327
#             );
#
#
#             var marker_b2b3fed6162afd76099ea9c8963a2dd1 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_cde09de2476d36b9ddcae14e91293104);
#
#
#             var marker_abf2f2fbf3e6f0890b940aca2a31f5c8 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_cde09de2476d36b9ddcae14e91293104);
#
#
#             feature_group_sub_group_cde09de2476d36b9ddcae14e91293104.addTo(map_89f5cfae0670fc7d90e14567fb4bc727);
#
#
#             var feature_group_sub_group_faac8211a975cf57ba78898dce6cf5be = L.featureGroup.subGroup(
#                 marker_cluster_31055fe429a9d1cb31c017fa7521e327
#             );
#
#
#             var marker_f232b79aadee9b1ad6b448f3f8373305 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_faac8211a975cf57ba78898dce6cf5be);
#
#
#             var marker_3199195741a213cb529cfaf2f95e4be6 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_faac8211a975cf57ba78898dce6cf5be);
#
#
#             feature_group_sub_group_faac8211a975cf57ba78898dce6cf5be.addTo(map_89f5cfae0670fc7d90e14567fb4bc727);
#
#
#             var layer_control_e98d74312e12616f059b7a944ad0c626_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_b84d1915529d108dabef4b12d5f51237,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_cde09de2476d36b9ddcae14e91293104,
#                     &quot;group2&quot; : feature_group_sub_group_faac8211a975cf57ba78898dce6cf5be,
#                 },
#             };
#             let layer_control_e98d74312e12616f059b7a944ad0c626 = L.control.layers(
#                 layer_control_e98d74312e12616f059b7a944ad0c626_layers.base_layers,
#                 layer_control_e98d74312e12616f059b7a944ad0c626_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_89f5cfae0670fc7d90e14567fb4bc727);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
