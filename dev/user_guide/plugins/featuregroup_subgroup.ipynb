# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_23b4a6f23feb7ae09c8468dff6ec1e57 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_23b4a6f23feb7ae09c8468dff6ec1e57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_23b4a6f23feb7ae09c8468dff6ec1e57 = L.map(
#                 &quot;map_23b4a6f23feb7ae09c8468dff6ec1e57&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc77033c28cfde9e739a26b8e9a2f25b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_dc77033c28cfde9e739a26b8e9a2f25b.addTo(map_23b4a6f23feb7ae09c8468dff6ec1e57);
#
#
#             var feature_group_72e15de64758b52fbae4531c5498cfaa = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_72e15de64758b52fbae4531c5498cfaa.addTo(map_23b4a6f23feb7ae09c8468dff6ec1e57);
#
#
#             var feature_group_sub_group_5c7d2f9f8bbd60e3f051d736045dc72d = L.featureGroup.subGroup(
#                 feature_group_72e15de64758b52fbae4531c5498cfaa
#             );
#
#
#             var marker_3b0c8ac240321737d31ff9c3baa3c35e = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_5c7d2f9f8bbd60e3f051d736045dc72d);
#
#
#             var marker_ff31f2bfe957fbb4eab1b9021bb3a723 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_5c7d2f9f8bbd60e3f051d736045dc72d);
#
#
#             feature_group_sub_group_5c7d2f9f8bbd60e3f051d736045dc72d.addTo(map_23b4a6f23feb7ae09c8468dff6ec1e57);
#
#
#             var feature_group_sub_group_290a290b6b2830bf3030593cb7e30a30 = L.featureGroup.subGroup(
#                 feature_group_72e15de64758b52fbae4531c5498cfaa
#             );
#
#
#             var marker_55af1bff4c51d6681c75577b80ca6bcb = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_290a290b6b2830bf3030593cb7e30a30);
#
#
#             var marker_de4a987e7d74fb3f4bf92e4d68013a13 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_290a290b6b2830bf3030593cb7e30a30);
#
#
#             feature_group_sub_group_290a290b6b2830bf3030593cb7e30a30.addTo(map_23b4a6f23feb7ae09c8468dff6ec1e57);
#
#
#             var layer_control_bc22fffab2712686b332d917af00fb06_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_dc77033c28cfde9e739a26b8e9a2f25b,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_72e15de64758b52fbae4531c5498cfaa,
#                     &quot;group1&quot; : feature_group_sub_group_5c7d2f9f8bbd60e3f051d736045dc72d,
#                     &quot;group2&quot; : feature_group_sub_group_290a290b6b2830bf3030593cb7e30a30,
#                 },
#             };
#             let layer_control_bc22fffab2712686b332d917af00fb06 = L.control.layers(
#                 layer_control_bc22fffab2712686b332d917af00fb06_layers.base_layers,
#                 layer_control_bc22fffab2712686b332d917af00fb06_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_23b4a6f23feb7ae09c8468dff6ec1e57);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3ff706b638bc9ec864c619a04d37e2e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3ff706b638bc9ec864c619a04d37e2e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3ff706b638bc9ec864c619a04d37e2e = L.map(
#                 &quot;map_d3ff706b638bc9ec864c619a04d37e2e&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cee67e6cbddf72bab0c1e53563c5c46d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cee67e6cbddf72bab0c1e53563c5c46d.addTo(map_d3ff706b638bc9ec864c619a04d37e2e);
#
#
#             var marker_cluster_cf0c45743caa2a385581d83c2b2654e9 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_cf0c45743caa2a385581d83c2b2654e9.addTo(map_d3ff706b638bc9ec864c619a04d37e2e);
#
#
#             var feature_group_sub_group_dc4acabd12ec3ef984c8f70cf76b1f4c = L.featureGroup.subGroup(
#                 marker_cluster_cf0c45743caa2a385581d83c2b2654e9
#             );
#
#
#             var marker_129a4194cac19ca646ab92c43fb25794 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_dc4acabd12ec3ef984c8f70cf76b1f4c);
#
#
#             var marker_e3d5c4fc6b629794c13d19bba4591848 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_dc4acabd12ec3ef984c8f70cf76b1f4c);
#
#
#             feature_group_sub_group_dc4acabd12ec3ef984c8f70cf76b1f4c.addTo(map_d3ff706b638bc9ec864c619a04d37e2e);
#
#
#             var feature_group_sub_group_e0d5543bf74b2ccb93509e8c00175304 = L.featureGroup.subGroup(
#                 marker_cluster_cf0c45743caa2a385581d83c2b2654e9
#             );
#
#
#             var marker_7422380044f7bbf7f1fcf3d0d06bc652 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_e0d5543bf74b2ccb93509e8c00175304);
#
#
#             var marker_f19bcaebe49e31bb31d7379350ee050f = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_e0d5543bf74b2ccb93509e8c00175304);
#
#
#             feature_group_sub_group_e0d5543bf74b2ccb93509e8c00175304.addTo(map_d3ff706b638bc9ec864c619a04d37e2e);
#
#
#             var layer_control_070f2a33476eea95583fd16fcbd7f3a8_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_cee67e6cbddf72bab0c1e53563c5c46d,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_dc4acabd12ec3ef984c8f70cf76b1f4c,
#                     &quot;group2&quot; : feature_group_sub_group_e0d5543bf74b2ccb93509e8c00175304,
#                 },
#             };
#             let layer_control_070f2a33476eea95583fd16fcbd7f3a8 = L.control.layers(
#                 layer_control_070f2a33476eea95583fd16fcbd7f3a8_layers.base_layers,
#                 layer_control_070f2a33476eea95583fd16fcbd7f3a8_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_d3ff706b638bc9ec864c619a04d37e2e);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
