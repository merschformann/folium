# %% [markdown]
# # GroupedLayerControl
#
# We can create a GroupedLayerControl and define what layers we want to group together. Those layers won't show up in the regular layer control.
#
# `GroupedLayerControl` takes the same arguments as `LayerControl`.
#
# By default, groups are exclusive, meaning only one layer in a group can be active at a time.

# %%
import folium
from folium.plugins import GroupedLayerControl

m = folium.Map([40., 70.], zoom_start=6)

fg1 = folium.FeatureGroup(name='g1')
fg2 = folium.FeatureGroup(name='g2')
fg3 = folium.FeatureGroup(name='g3')
folium.Marker([40, 74]).add_to(fg1)
folium.Marker([38, 72]).add_to(fg2)
folium.Marker([40, 72]).add_to(fg3)
m.add_child(fg1)
m.add_child(fg2)
m.add_child(fg3)

folium.LayerControl(collapsed=False).add_to(m)

GroupedLayerControl(
    groups={'groups1': [fg1, fg2]},
    collapsed=False,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dd3e9a5d04b4b2dc16590ab1ec307316 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dd3e9a5d04b4b2dc16590ab1ec307316&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dd3e9a5d04b4b2dc16590ab1ec307316 = L.map(
#                 &quot;map_dd3e9a5d04b4b2dc16590ab1ec307316&quot;,
#                 {
#                     center: [40.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30c4e63a8368e7c4d987de0cb25cdaab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_30c4e63a8368e7c4d987de0cb25cdaab.addTo(map_dd3e9a5d04b4b2dc16590ab1ec307316);
#
#
#             var feature_group_0f13328eb87bd468816b95c4ddd98aa0 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_9261dbd8c36de105343172a33f60f653 = L.marker(
#                 [40.0, 74.0],
#                 {}
#             ).addTo(feature_group_0f13328eb87bd468816b95c4ddd98aa0);
#
#
#             feature_group_0f13328eb87bd468816b95c4ddd98aa0.addTo(map_dd3e9a5d04b4b2dc16590ab1ec307316);
#
#
#             var feature_group_036c69c1f287ba100d5fb36080c2f478 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_8b4bf6ed9aef28263154eddc59e0ee13 = L.marker(
#                 [38.0, 72.0],
#                 {}
#             ).addTo(feature_group_036c69c1f287ba100d5fb36080c2f478);
#
#
#             feature_group_036c69c1f287ba100d5fb36080c2f478.addTo(map_dd3e9a5d04b4b2dc16590ab1ec307316);
#
#
#             var feature_group_81216c1846d2463c7b378a65151370ef = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_0d4d03b97aedeaf0e6cc26e9403cccc9 = L.marker(
#                 [40.0, 72.0],
#                 {}
#             ).addTo(feature_group_81216c1846d2463c7b378a65151370ef);
#
#
#             feature_group_81216c1846d2463c7b378a65151370ef.addTo(map_dd3e9a5d04b4b2dc16590ab1ec307316);
#
#
#             var layer_control_df5104210f2a3f38f0d51de42b416914_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_30c4e63a8368e7c4d987de0cb25cdaab,
#                 },
#                 overlays :  {
#                     &quot;g3&quot; : feature_group_81216c1846d2463c7b378a65151370ef,
#                 },
#             };
#             let layer_control_df5104210f2a3f38f0d51de42b416914 = L.control.layers(
#                 layer_control_df5104210f2a3f38f0d51de42b416914_layers.base_layers,
#                 layer_control_df5104210f2a3f38f0d51de42b416914_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_dd3e9a5d04b4b2dc16590ab1ec307316);
#
#
#
#
#             L.control.groupedLayers(
#                 null,
#                 {
#                     &quot;groups1&quot; : {
#                         &quot;g1&quot; : feature_group_0f13328eb87bd468816b95c4ddd98aa0,
#                         &quot;g2&quot; : feature_group_036c69c1f287ba100d5fb36080c2f478,
#                     },
#                 },
#                 {&quot;collapsed&quot;: false, &quot;exclusiveGroups&quot;: [&quot;groups1&quot;]},
#             ).addTo(map_dd3e9a5d04b4b2dc16590ab1ec307316);
#             feature_group_036c69c1f287ba100d5fb36080c2f478.remove();
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# It's also possible to have check boxes instead of radio buttons, so multiple layers within a group can be active.
#
# In this example the layers are not shown by default, but can all be activated.

# %%
m = folium.Map([40., 70.], zoom_start=6)

fg1 = folium.FeatureGroup(name='g1', show=False)
fg2 = folium.FeatureGroup(name='g2', show=False)
fg3 = folium.FeatureGroup(name='g3')
folium.Marker([40, 74]).add_to(fg1)
folium.Marker([38, 72]).add_to(fg2)
folium.Marker([40, 72]).add_to(fg3)
m.add_child(fg1)
m.add_child(fg2)
m.add_child(fg3)

folium.LayerControl(collapsed=False).add_to(m)

GroupedLayerControl(
    groups={'groups1': [fg1, fg2]},
    exclusive_groups=False,
    collapsed=False,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c27f986c5472e6c636f39d2a8d86232f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c27f986c5472e6c636f39d2a8d86232f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c27f986c5472e6c636f39d2a8d86232f = L.map(
#                 &quot;map_c27f986c5472e6c636f39d2a8d86232f&quot;,
#                 {
#                     center: [40.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b73f7460fbd72b9b6f4ffbbca6fab5a6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b73f7460fbd72b9b6f4ffbbca6fab5a6.addTo(map_c27f986c5472e6c636f39d2a8d86232f);
#
#
#             var feature_group_6d41b75cb67ee0ddcdcffa11e671e0b1 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_38f4eae53e704dfeb4b6f48f9c385ea0 = L.marker(
#                 [40.0, 74.0],
#                 {}
#             ).addTo(feature_group_6d41b75cb67ee0ddcdcffa11e671e0b1);
#
#
#             var feature_group_b587484c4dc947a472761e2a38dfdabf = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_9dd2e56d72f2f0cfbed437830cfe2b8a = L.marker(
#                 [38.0, 72.0],
#                 {}
#             ).addTo(feature_group_b587484c4dc947a472761e2a38dfdabf);
#
#
#             var feature_group_bb08f721e51b7c4fbda2a930cfb7f18c = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_0592eb27637127166a5d020a8be4978c = L.marker(
#                 [40.0, 72.0],
#                 {}
#             ).addTo(feature_group_bb08f721e51b7c4fbda2a930cfb7f18c);
#
#
#             feature_group_bb08f721e51b7c4fbda2a930cfb7f18c.addTo(map_c27f986c5472e6c636f39d2a8d86232f);
#
#
#             var layer_control_ecb86ef5d77b6d18be34525926970eea_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_b73f7460fbd72b9b6f4ffbbca6fab5a6,
#                 },
#                 overlays :  {
#                     &quot;g3&quot; : feature_group_bb08f721e51b7c4fbda2a930cfb7f18c,
#                 },
#             };
#             let layer_control_ecb86ef5d77b6d18be34525926970eea = L.control.layers(
#                 layer_control_ecb86ef5d77b6d18be34525926970eea_layers.base_layers,
#                 layer_control_ecb86ef5d77b6d18be34525926970eea_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_c27f986c5472e6c636f39d2a8d86232f);
#
#
#
#
#             L.control.groupedLayers(
#                 null,
#                 {
#                     &quot;groups1&quot; : {
#                         &quot;g1&quot; : feature_group_6d41b75cb67ee0ddcdcffa11e671e0b1,
#                         &quot;g2&quot; : feature_group_b587484c4dc947a472761e2a38dfdabf,
#                     },
#                 },
#                 {&quot;collapsed&quot;: false},
#             ).addTo(map_c27f986c5472e6c636f39d2a8d86232f);
#             feature_group_b587484c4dc947a472761e2a38dfdabf.remove();
#             feature_group_6d41b75cb67ee0ddcdcffa11e671e0b1.remove();
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
