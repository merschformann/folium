# %% [markdown]
# # GroupedLayerControl
#
# We can create a GroupedLayerControl and define what layers we want to group together. Those layers won't show up in the regular layer control.
#
# `GroupedLayerControl` takes the same arguments as `LayerControl`.
#
# By default, groups are exclusive, meaning only one layer in a group can be active at a time.

# %%
import folium
from folium.plugins import GroupedLayerControl

m = folium.Map([40., 70.], zoom_start=6)

fg1 = folium.FeatureGroup(name='g1')
fg2 = folium.FeatureGroup(name='g2')
fg3 = folium.FeatureGroup(name='g3')
folium.Marker([40, 74]).add_to(fg1)
folium.Marker([38, 72]).add_to(fg2)
folium.Marker([40, 72]).add_to(fg3)
m.add_child(fg1)
m.add_child(fg2)
m.add_child(fg3)

folium.LayerControl(collapsed=False).add_to(m)

GroupedLayerControl(
    groups={'groups1': [fg1, fg2]},
    collapsed=False,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_456ae2b784800fe73ee9ee893b8fef4e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_456ae2b784800fe73ee9ee893b8fef4e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_456ae2b784800fe73ee9ee893b8fef4e = L.map(
#                 &quot;map_456ae2b784800fe73ee9ee893b8fef4e&quot;,
#                 {
#                     center: [40.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e1f42a1a16a3edae0f3d75e581c56c28 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e1f42a1a16a3edae0f3d75e581c56c28.addTo(map_456ae2b784800fe73ee9ee893b8fef4e);
#
#
#             var feature_group_08ef0a636fc64b4529788219f2a605d7 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_4d659684c13df46e6c5db402f2eb831f = L.marker(
#                 [40.0, 74.0],
#                 {}
#             ).addTo(feature_group_08ef0a636fc64b4529788219f2a605d7);
#
#
#             feature_group_08ef0a636fc64b4529788219f2a605d7.addTo(map_456ae2b784800fe73ee9ee893b8fef4e);
#
#
#             var feature_group_be2bde11d7859e2c5f12aa2501af2882 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_d8559933904c2c4f0d30250a8959990b = L.marker(
#                 [38.0, 72.0],
#                 {}
#             ).addTo(feature_group_be2bde11d7859e2c5f12aa2501af2882);
#
#
#             feature_group_be2bde11d7859e2c5f12aa2501af2882.addTo(map_456ae2b784800fe73ee9ee893b8fef4e);
#
#
#             var feature_group_316d4ce514601c9e6aa7a63ae8295b87 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_8e16f182b8c98977c224734388458c60 = L.marker(
#                 [40.0, 72.0],
#                 {}
#             ).addTo(feature_group_316d4ce514601c9e6aa7a63ae8295b87);
#
#
#             feature_group_316d4ce514601c9e6aa7a63ae8295b87.addTo(map_456ae2b784800fe73ee9ee893b8fef4e);
#
#
#             var layer_control_3be1c4bb13f0d0fdce7ea0b18add07e2_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_e1f42a1a16a3edae0f3d75e581c56c28,
#                 },
#                 overlays :  {
#                     &quot;g3&quot; : feature_group_316d4ce514601c9e6aa7a63ae8295b87,
#                 },
#             };
#             let layer_control_3be1c4bb13f0d0fdce7ea0b18add07e2 = L.control.layers(
#                 layer_control_3be1c4bb13f0d0fdce7ea0b18add07e2_layers.base_layers,
#                 layer_control_3be1c4bb13f0d0fdce7ea0b18add07e2_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_456ae2b784800fe73ee9ee893b8fef4e);
#
#
#
#
#             L.control.groupedLayers(
#                 null,
#                 {
#                     &quot;groups1&quot; : {
#                         &quot;g1&quot; : feature_group_08ef0a636fc64b4529788219f2a605d7,
#                         &quot;g2&quot; : feature_group_be2bde11d7859e2c5f12aa2501af2882,
#                     },
#                 },
#                 {&quot;collapsed&quot;: false, &quot;exclusiveGroups&quot;: [&quot;groups1&quot;]},
#             ).addTo(map_456ae2b784800fe73ee9ee893b8fef4e);
#             feature_group_be2bde11d7859e2c5f12aa2501af2882.remove();
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# It's also possible to have check boxes instead of radio buttons, so multiple layers within a group can be active.
#
# In this example the layers are not shown by default, but can all be activated.

# %%
m = folium.Map([40., 70.], zoom_start=6)

fg1 = folium.FeatureGroup(name='g1', show=False)
fg2 = folium.FeatureGroup(name='g2', show=False)
fg3 = folium.FeatureGroup(name='g3')
folium.Marker([40, 74]).add_to(fg1)
folium.Marker([38, 72]).add_to(fg2)
folium.Marker([40, 72]).add_to(fg3)
m.add_child(fg1)
m.add_child(fg2)
m.add_child(fg3)

folium.LayerControl(collapsed=False).add_to(m)

GroupedLayerControl(
    groups={'groups1': [fg1, fg2]},
    exclusive_groups=False,
    collapsed=False,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6bc8cf7af305e29ade8cf9521813f5f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6bc8cf7af305e29ade8cf9521813f5f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6bc8cf7af305e29ade8cf9521813f5f1 = L.map(
#                 &quot;map_6bc8cf7af305e29ade8cf9521813f5f1&quot;,
#                 {
#                     center: [40.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4f3d83388453b872220518a559cc0b8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f4f3d83388453b872220518a559cc0b8.addTo(map_6bc8cf7af305e29ade8cf9521813f5f1);
#
#
#             var feature_group_675206fc7ea426f1e327ec4f7ada7926 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_2219468fc46054f06e827f5a7ca423ec = L.marker(
#                 [40.0, 74.0],
#                 {}
#             ).addTo(feature_group_675206fc7ea426f1e327ec4f7ada7926);
#
#
#             var feature_group_1f55b31e0c402a97d991f5f3d691917f = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_3c338656532a2017f32991fa45bac88d = L.marker(
#                 [38.0, 72.0],
#                 {}
#             ).addTo(feature_group_1f55b31e0c402a97d991f5f3d691917f);
#
#
#             var feature_group_6750dc880dafb84459da8f3d38712d55 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_0b96760ceaebddaa0c3d97852216292d = L.marker(
#                 [40.0, 72.0],
#                 {}
#             ).addTo(feature_group_6750dc880dafb84459da8f3d38712d55);
#
#
#             feature_group_6750dc880dafb84459da8f3d38712d55.addTo(map_6bc8cf7af305e29ade8cf9521813f5f1);
#
#
#             var layer_control_e4cf5f669825b37259d63089b25f82e4_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_f4f3d83388453b872220518a559cc0b8,
#                 },
#                 overlays :  {
#                     &quot;g3&quot; : feature_group_6750dc880dafb84459da8f3d38712d55,
#                 },
#             };
#             let layer_control_e4cf5f669825b37259d63089b25f82e4 = L.control.layers(
#                 layer_control_e4cf5f669825b37259d63089b25f82e4_layers.base_layers,
#                 layer_control_e4cf5f669825b37259d63089b25f82e4_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_6bc8cf7af305e29ade8cf9521813f5f1);
#
#
#
#
#             L.control.groupedLayers(
#                 null,
#                 {
#                     &quot;groups1&quot; : {
#                         &quot;g1&quot; : feature_group_675206fc7ea426f1e327ec4f7ada7926,
#                         &quot;g2&quot; : feature_group_1f55b31e0c402a97d991f5f3d691917f,
#                     },
#                 },
#                 {&quot;collapsed&quot;: false},
#             ).addTo(map_6bc8cf7af305e29ade8cf9521813f5f1);
#             feature_group_1f55b31e0c402a97d991f5f3d691917f.remove();
#             feature_group_675206fc7ea426f1e327ec4f7ada7926.remove();
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
