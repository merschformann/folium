# %% [markdown]
# # GroupedLayerControl
#
# We can create a GroupedLayerControl and define what layers we want to group together. Those layers won't show up in the regular layer control.
#
# `GroupedLayerControl` takes the same arguments as `LayerControl`.
#
# By default, groups are exclusive, meaning only one layer in a group can be active at a time.

# %%
import folium
from folium.plugins import GroupedLayerControl

m = folium.Map([40., 70.], zoom_start=6)

fg1 = folium.FeatureGroup(name='g1')
fg2 = folium.FeatureGroup(name='g2')
fg3 = folium.FeatureGroup(name='g3')
folium.Marker([40, 74]).add_to(fg1)
folium.Marker([38, 72]).add_to(fg2)
folium.Marker([40, 72]).add_to(fg3)
m.add_child(fg1)
m.add_child(fg2)
m.add_child(fg3)

folium.LayerControl(collapsed=False).add_to(m)

GroupedLayerControl(
    groups={'groups1': [fg1, fg2]},
    collapsed=False,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f2871afdd8c9eedd3920a8200f62d53 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f2871afdd8c9eedd3920a8200f62d53&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f2871afdd8c9eedd3920a8200f62d53 = L.map(
#                 &quot;map_8f2871afdd8c9eedd3920a8200f62d53&quot;,
#                 {
#                     center: [40.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b5091ec2eaef81c5cdcc448a96b532a9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b5091ec2eaef81c5cdcc448a96b532a9.addTo(map_8f2871afdd8c9eedd3920a8200f62d53);
#
#
#             var feature_group_24200276b6b6c7238fa0879f2821e0fe = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_1e75a61273738a1b19ad5e0a5e81729a = L.marker(
#                 [40.0, 74.0],
#                 {}
#             ).addTo(feature_group_24200276b6b6c7238fa0879f2821e0fe);
#
#
#             feature_group_24200276b6b6c7238fa0879f2821e0fe.addTo(map_8f2871afdd8c9eedd3920a8200f62d53);
#
#
#             var feature_group_359755055d11e8fc004af565eb4af252 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_d52b1b4f849b47a34b270566c998b7f3 = L.marker(
#                 [38.0, 72.0],
#                 {}
#             ).addTo(feature_group_359755055d11e8fc004af565eb4af252);
#
#
#             feature_group_359755055d11e8fc004af565eb4af252.addTo(map_8f2871afdd8c9eedd3920a8200f62d53);
#
#
#             var feature_group_260b2c9fa03aadcf7ea38bc292797858 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_97357f895766d1242eeac91164d0489c = L.marker(
#                 [40.0, 72.0],
#                 {}
#             ).addTo(feature_group_260b2c9fa03aadcf7ea38bc292797858);
#
#
#             feature_group_260b2c9fa03aadcf7ea38bc292797858.addTo(map_8f2871afdd8c9eedd3920a8200f62d53);
#
#
#             var layer_control_d27ba61982201689b81470483d9ae6a9_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_b5091ec2eaef81c5cdcc448a96b532a9,
#                 },
#                 overlays :  {
#                     &quot;g3&quot; : feature_group_260b2c9fa03aadcf7ea38bc292797858,
#                 },
#             };
#             let layer_control_d27ba61982201689b81470483d9ae6a9 = L.control.layers(
#                 layer_control_d27ba61982201689b81470483d9ae6a9_layers.base_layers,
#                 layer_control_d27ba61982201689b81470483d9ae6a9_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_8f2871afdd8c9eedd3920a8200f62d53);
#
#
#
#
#             L.control.groupedLayers(
#                 null,
#                 {
#                     &quot;groups1&quot; : {
#                         &quot;g1&quot; : feature_group_24200276b6b6c7238fa0879f2821e0fe,
#                         &quot;g2&quot; : feature_group_359755055d11e8fc004af565eb4af252,
#                     },
#                 },
#                 {&quot;collapsed&quot;: false, &quot;exclusiveGroups&quot;: [&quot;groups1&quot;]},
#             ).addTo(map_8f2871afdd8c9eedd3920a8200f62d53);
#             feature_group_359755055d11e8fc004af565eb4af252.remove();
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# It's also possible to have check boxes instead of radio buttons, so multiple layers within a group can be active.
#
# In this example the layers are not shown by default, but can all be activated.

# %%
m = folium.Map([40., 70.], zoom_start=6)

fg1 = folium.FeatureGroup(name='g1', show=False)
fg2 = folium.FeatureGroup(name='g2', show=False)
fg3 = folium.FeatureGroup(name='g3')
folium.Marker([40, 74]).add_to(fg1)
folium.Marker([38, 72]).add_to(fg2)
folium.Marker([40, 72]).add_to(fg3)
m.add_child(fg1)
m.add_child(fg2)
m.add_child(fg3)

folium.LayerControl(collapsed=False).add_to(m)

GroupedLayerControl(
    groups={'groups1': [fg1, fg2]},
    exclusive_groups=False,
    collapsed=False,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a812bae8267552334d49359fc03febd1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a812bae8267552334d49359fc03febd1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a812bae8267552334d49359fc03febd1 = L.map(
#                 &quot;map_a812bae8267552334d49359fc03febd1&quot;,
#                 {
#                     center: [40.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ef31ccd9d3ed9c38ef6e3fc4c1a8c0d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5ef31ccd9d3ed9c38ef6e3fc4c1a8c0d.addTo(map_a812bae8267552334d49359fc03febd1);
#
#
#             var feature_group_fb04ca65c31032183c149ba13107bbbe = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_03c53f863aa03aea46477c8daccadcec = L.marker(
#                 [40.0, 74.0],
#                 {}
#             ).addTo(feature_group_fb04ca65c31032183c149ba13107bbbe);
#
#
#             var feature_group_59e3357e2237eed10a89416f7e0c7b19 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_ecf775ad51364387444ab0b6ce0f6bed = L.marker(
#                 [38.0, 72.0],
#                 {}
#             ).addTo(feature_group_59e3357e2237eed10a89416f7e0c7b19);
#
#
#             var feature_group_478ad867543582b8f42a8eca3f0e813b = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_45d1128d6e26b8ace3fbca193cd04b41 = L.marker(
#                 [40.0, 72.0],
#                 {}
#             ).addTo(feature_group_478ad867543582b8f42a8eca3f0e813b);
#
#
#             feature_group_478ad867543582b8f42a8eca3f0e813b.addTo(map_a812bae8267552334d49359fc03febd1);
#
#
#             var layer_control_7dcf7911f6e73f8aff9ef6b44daa8707_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_5ef31ccd9d3ed9c38ef6e3fc4c1a8c0d,
#                 },
#                 overlays :  {
#                     &quot;g3&quot; : feature_group_478ad867543582b8f42a8eca3f0e813b,
#                 },
#             };
#             let layer_control_7dcf7911f6e73f8aff9ef6b44daa8707 = L.control.layers(
#                 layer_control_7dcf7911f6e73f8aff9ef6b44daa8707_layers.base_layers,
#                 layer_control_7dcf7911f6e73f8aff9ef6b44daa8707_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_a812bae8267552334d49359fc03febd1);
#
#
#
#
#             L.control.groupedLayers(
#                 null,
#                 {
#                     &quot;groups1&quot; : {
#                         &quot;g1&quot; : feature_group_fb04ca65c31032183c149ba13107bbbe,
#                         &quot;g2&quot; : feature_group_59e3357e2237eed10a89416f7e0c7b19,
#                     },
#                 },
#                 {&quot;collapsed&quot;: false},
#             ).addTo(map_a812bae8267552334d49359fc03febd1);
#             feature_group_fb04ca65c31032183c149ba13107bbbe.remove();
#             feature_group_59e3357e2237eed10a89416f7e0c7b19.remove();
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
